# %%
import os
import pandas as pd
path = "./obstacles/N10"
file = '/result/result2022-08-30 15-47-47.654.txt'
result = pd.read_table(path + file, sep = ";")
result
# Out:
#                  TimeStamp  Number of States Shield Position  Local Shield  \
# 0  2022-08-30 15-47-47.654               101           prior         False
#
#    Episode  Total Episodes  Undiscounted Reward  Discounted Reward  \
# 0        1               2                 -6.0          -8.986236
#
#    Number of Bad States  Number of Steps  Time Spent  \
# 0                   0.0             27.0        8242
#
#    Average Undiscounted reward  Average Discounted reward  \
# 0                         -6.0                  -8.986236
#
#    Average time spent   Average number of Bad States  Average number of Steps  \
# 0                 8242                           0.0                     27.0
#
#    Exploration Constant  Number of Simulations
# 0                  40.0                32768.0

# %%
trajectory_file = "/log/Trajectory-2022-08-30 15-47-47.654-shield-prior-Episode-1.txt"
tra = pd.read_table(path + trajectory_file, sep = ";", index_col = None)
sum(tra.is_bad_state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-0d0b835c4dc4> in <module>
#       1 trajectory_file = "/log/Trajectory-2022-08-30 15-47-47.654-shield-prior-Episode-1.txt"
# ----> 2 tra = pd.read_table(path + trajectory_file, sep = ";", index_col = -1)
#       3 sum(tra.is_bad_state)
#
# E:\Users\ss7dr\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
tra
# Out:
#                prism_state                               prism_belief_support  \
# placement                0                                                [0]
# west                    25                               [48, 65, 53, 57, 25]
# west                    15            [33, 37, 5, 38, 55, 43, 28, 45, 47, 15]
# east                     5  [33, 35, 5, 37, 8, 45, 13, 17, 18, 23, 25, 27,...
# west                    15  [33, 65, 35, 37, 38, 43, 45, 47, 15, 48, 18, 5...
# west                     5  [33, 35, 3, 5, 37, 38, 7, 8, 43, 45, 13, 15, 4...
# west                     5  [33, 35, 3, 5, 37, 7, 8, 13, 45, 15, 17, 18, 2...
# west                     5       [17, 18, 3, 35, 5, 7, 23, 8, 25, 27, 13, 15]
# south                    5                       [17, 3, 5, 7, 8, 25, 13, 15]
# west                     6  [4, 5, 6, 7, 8, 9, 10, 14, 15, 16, 17, 18, 19,...
# south                    6                     [16, 17, 4, 5, 6, 7, 8, 9, 10]
# ...
